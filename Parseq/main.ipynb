# %%
# !git clone https://github.com/baudm/parseq.git
# %cd parseq
# Out:
# d:\Important Documents\IIT Mandi Academics\4th Sem\IC 201P DP\Parseq\parseq
# fatal: destination path 'parseq' already exists and is not an empty directory.
# C:\Users\Bhupesh Yadav\AppData\Roaming\Python\Python311\site-packages\IPython\core\magics\osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# !python -m venv venv
# !venv\Scripts\activate

# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cpu
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cpu
# Requirement already satisfied: torch in c:\users\bhupesh yadav\appdata\local\programs\python\python311\lib\site-packages (2.6.0)
# Requirement already satisfied: torchvision in c:\users\bhupesh yadav\appdata\local\programs\python\python311\lib\site-packages (0.21.0)
# Requirement already satisfied: torchaudio in c:\users\bhupesh yadav\appdata\local\programs\python\python311\lib\site-packages (2.6.0+cpu)
# Requirement already satisfied: filelock in c:\users\bhupesh yadav\appdata\local\programs\python\python311\lib\site-packages (from torch) (3.16.1)
# Collecting typing-extensions>=4.10.0 (from torch)
#   Downloading https://download.pytorch.org/whl/typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: networkx in c:\users\bhupesh yadav\appdata\local\programs\python\python311\lib\site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\bhupesh yadav\appdata\local\programs\python\python311\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\bhupesh yadav\appdata\local\programs\python\python311\lib\site-packages (from torch) (2024.9.0)
# Collecting sympy==1.13.1 (from torch)
#   Downloading https://download.pytorch.org/whl/sympy-1.13.1-py3-none-any.whl (6.2 MB)
#      ---------------------------------------- 0.0/6.2 MB ? eta -:--:--
#      ----- ---------------------------------- 0.8/6.2 MB 4.8 MB/s eta 0:00:02
#      ---------- ----------------------------- 1.6/6.2 MB 4.2 MB/s eta 0:00:02
#      --------------- ------------------------ 2.4/6.2 MB 3.7 MB/s eta 0:00:02
#      -------------------- ------------------- 3.1/6.2 MB 4.0 MB/s eta 0:00:01
#      ------------------------- -------------- 3.9/6.2 MB 3.9 MB/s eta 0:00:01
#      ------------------------------ --------- 4.7/6.2 MB 3.9 MB/s eta 0:00:01
#      --------------------------------- ------ 5.2/6.2 MB 3.7 MB/s eta 0:00:01
#      ------------------------------------- -- 5.8/6.2 MB 3.6 MB/s eta 0:00:01
#      ---------------------------------------- 6.2/6.2 MB 3.6 MB/s eta 0:00:00
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\bhupesh yadav\appdata\local\programs\python\python311\lib\site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in c:\users\bhupesh yadav\appdata\local\programs\python\python311\lib\site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\bhupesh yadav\appdata\local\programs\python\python311\lib\site-packages (from torchvision) (11.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\bhupesh yadav\appdata\local\programs\python\python311\lib\site-packages (from jinja2->torch) (3.0.2)
# Downloading https://download.pytorch.org/whl/typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Installing collected packages: typing-extensions, sympy
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.9.0
#     Uninstalling typing_extensions-4.9.0:
#       Successfully uninstalled typing_extensions-4.9.0
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.12
#     Uninstalling sympy-1.12:
#       Successfully uninstalled sympy-1.12
# Successfully installed sympy-1.13.1 typing-extensions-4.12.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-google-genai 2.1.2 requires google-ai-generativelanguage<0.7.0,>=0.6.16, but you have google-ai-generativelanguage 0.6.15 which is incompatible.
# tensorflow-intel 2.18.0 requires ml-dtypes<0.5.0,>=0.4.0, but you have ml-dtypes 0.5.1 which is incompatible.
# tensorflow-intel 2.18.0 requires tensorboard<2.19,>=2.18, but you have tensorboard 2.19.0 which is incompatible.
# thinc 8.3.2 requires numpy<2.1.0,>=2.0.0; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.

# %%
# !pip install -r requirements/core.txt
# !pip install -r requirements/train.txt
# !pip install -r requirements/test.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cpu
# Collecting aiohttp==3.9.3 (from -r requirements/core.txt (line 3))
#   Using cached aiohttp-3.9.3-cp311-cp311-win_amd64.whl.metadata (7.6 kB)
# Collecting aiosignal==1.3.1 (from -r requirements/core.txt (line 4))
#   Using cached aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting async-timeout==4.0.3 (from -r requirements/core.txt (line 5))
#   Using cached async_timeout-4.0.3-py3-none-any.whl.metadata (4.2 kB)
# Collecting attrs==23.2.0 (from -r requirements/core.txt (line 6))
#   Using cached attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting certifi==2024.2.2 (from -r requirements/core.txt (line 7))
#   Using cached certifi-2024.2.2-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: charset-normalizer==3.3.2 in c:\users\bhupesh yadav\appdata\local\programs\python\python311\lib\site-packages (from -r requirements/core.txt (line 8)) (3.3.2)
# Requirement already satisfied: click==8.1.7 in c:\users\bhupesh yadav\appdata\local\programs\python\python311\lib\site-packages (from -r requirements/core.txt (line 9)) (8.1.7)
# Collecting filelock==3.13.1 (from -r requirements/core.txt (line 10))
#   Using cached https://download.pytorch.org/whl/filelock-3.13.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting frozenlist==1.4.1 (from -r requirements/core.txt (line 11))
#   Using cached frozenlist-1.4.1-cp311-cp311-win_amd64.whl.metadata (12 kB)
# Collecting fsspec==2024.2.0 (from -r requirements/core.txt (line 12))
#   Using cached https://download.pytorch.org/whl/fsspec-2024.2.0-py3-none-any.whl (170 kB)
# Collecting huggingface-hub==0.20.3 (from -r requirements/core.txt (line 13))
#   Using cached huggingface_hub-0.20.3-py3-none-any.whl.metadata (12 kB)
# Collecting idna==3.6 (from -r requirements/core.txt (line 14))
#   Using cached idna-3.6-py3-none-any.whl.metadata (9.9 kB)
# Collecting jinja2==3.1.3 (from -r requirements/core.txt (line 15))
#   Using cached https://download.pytorch.org/whl/Jinja2-3.1.3-py3-none-any.whl (133 kB)
# Collecting joblib==1.3.2 (from -r requirements/core.txt (line 16))
#   Using cached joblib-1.3.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting lightning-utilities==0.10.1 (from -r requirements/core.txt (line 17))
#   Using cached lightning_utilities-0.10.1-py3-none-any.whl.metadata (4.8 kB)
# Collecting markupsafe==2.1.5 (from -r requirements/core.txt (line 18))
#   Using cached https://download.pytorch.org/whl/MarkupSafe-2.1.5-cp311-cp311-win_amd64.whl (17 kB)
# Requirement already satisfied: mpmath==1.3.0 in c:\users\bhupesh yadav\appdata\local\programs\python\python311\lib\site-packages (from -r requirements/core.txt (line 19)) (1.3.0)
# Collecting multidict==6.0.5 (from -r requirements/core.txt (line 20))
#   Using cached multidict-6.0.5-cp311-cp311-win_amd64.whl.metadata (4.3 kB)
# Collecting networkx==3.2.1 (from -r requirements/core.txt (line 21))
#   Using cached https://download.pytorch.org/whl/networkx-3.2.1-py3-none-any.whl (1.6 MB)
# Collecting nltk==3.8.1 (from -r requirements/core.txt (line 22))
#   Using cached nltk-3.8.1-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: numpy==1.26.4 in c:\users\bhupesh yadav\appdata\local\programs\python\python311\lib\site-packages (from -r requirements/core.txt (line 23)) (1.26.4)
# Collecting packaging==23.2 (from -r requirements/core.txt (line 24))
#   Using cached packaging-23.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting pillow==10.2.0 (from -r requirements/core.txt (line 25))
#   Using cached https://download.pytorch.org/whl/pillow-10.2.0-cp311-cp311-win_amd64.whl (2.6 MB)
# Collecting pytorch-lightning==2.2.0.post0 (from -r requirements/core.txt (line 26))
#   Using cached pytorch_lightning-2.2.0.post0-py3-none-any.whl.metadata (21 kB)
# Collecting pyyaml==6.0.1 (from -r requirements/core.txt (line 27))
#   Using cached PyYAML-6.0.1-cp311-cp311-win_amd64.whl.metadata (2.1 kB)
# Collecting regex==2023.12.25 (from -r requirements/core.txt (line 28))
#   Using cached regex-2023.12.25-cp311-cp311-win_amd64.whl.metadata (41 kB)
# Collecting requests==2.31.0 (from -r requirements/core.txt (line 29))
#   Using cached requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting safetensors==0.4.2 (from -r requirements/core.txt (line 30))
#   Using cached safetensors-0.4.2-cp311-none-win_amd64.whl.metadata (3.9 kB)
# Collecting sympy==1.12 (from -r requirements/core.txt (line 31))
#   Using cached https://download.pytorch.org/whl/sympy-1.12-py3-none-any.whl (5.7 MB)
# Collecting timm==0.9.16 (from -r requirements/core.txt (line 32))
#   Using cached timm-0.9.16-py3-none-any.whl.metadata (38 kB)
# Collecting torch==2.2.1+cpu (from -r requirements/core.txt (line 33))
#   Using cached https://download.pytorch.org/whl/cpu/torch-2.2.1%2Bcpu-cp311-cp311-win_amd64.whl (200.8 MB)
# Collecting torchmetrics==1.3.1 (from -r requirements/core.txt (line 34))
#   Using cached torchmetrics-1.3.1-py3-none-any.whl.metadata (19 kB)
# Collecting torchvision==0.17.1+cpu (from -r requirements/core.txt (line 35))
#   Using cached https://download.pytorch.org/whl/cpu/torchvision-0.17.1%2Bcpu-cp311-cp311-win_amd64.whl (1.2 MB)
# Requirement already satisfied: tqdm==4.66.2 in c:\users\bhupesh yadav\appdata\local\programs\python\python311\lib\site-packages (from -r requirements/core.txt (line 36)) (4.66.2)
# Collecting typing-extensions==4.9.0 (from -r requirements/core.txt (line 37))
#   Using cached https://download.pytorch.org/whl/typing_extensions-4.9.0-py3-none-any.whl (32 kB)
# Requirement already satisfied: urllib3==2.2.1 in c:\users\bhupesh yadav\appdata\local\programs\python\python311\lib\site-packages (from -r requirements/core.txt (line 38)) (2.2.1)
# Collecting yarl==1.9.4 (from -r requirements/core.txt (line 39))
#   Using cached yarl-1.9.4-cp311-cp311-win_amd64.whl.metadata (32 kB)
# Requirement already satisfied: setuptools==69.1.0 in c:\users\bhupesh yadav\appdata\local\programs\python\python311\lib\site-packages (from -r requirements/core.txt (line 42)) (69.1.0)
# Requirement already satisfied: colorama in c:\users\bhupesh yadav\appdata\local\programs\python\python311\lib\site-packages (from click==8.1.7->-r requirements/core.txt (line 9)) (0.4.6)
# Using cached aiohttp-3.9.3-cp311-cp311-win_amd64.whl (365 kB)
# Using cached aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Using cached async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Using cached attrs-23.2.0-py3-none-any.whl (60 kB)
# Using cached certifi-2024.2.2-py3-none-any.whl (163 kB)
# Using cached https://download.pytorch.org/whl/filelock-3.13.1-py3-none-any.whl (11 kB)
# Using cached frozenlist-1.4.1-cp311-cp311-win_amd64.whl (50 kB)
# Using cached huggingface_hub-0.20.3-py3-none-any.whl (330 kB)
# Using cached idna-3.6-py3-none-any.whl (61 kB)
# Using cached joblib-1.3.2-py3-none-any.whl (302 kB)
# Using cached lightning_utilities-0.10.1-py3-none-any.whl (24 kB)
# Using cached multidict-6.0.5-cp311-cp311-win_amd64.whl (28 kB)
# Using cached nltk-3.8.1-py3-none-any.whl (1.5 MB)
# Using cached packaging-23.2-py3-none-any.whl (53 kB)
# Using cached pytorch_lightning-2.2.0.post0-py3-none-any.whl (800 kB)
# Using cached PyYAML-6.0.1-cp311-cp311-win_amd64.whl (144 kB)
# Using cached regex-2023.12.25-cp311-cp311-win_amd64.whl (269 kB)
# Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# Using cached safetensors-0.4.2-cp311-none-win_amd64.whl (269 kB)
# Using cached timm-0.9.16-py3-none-any.whl (2.2 MB)
# Using cached torchmetrics-1.3.1-py3-none-any.whl (840 kB)
# Using cached yarl-1.9.4-cp311-cp311-win_amd64.whl (76 kB)
# Installing collected packages: typing-extensions, sympy, safetensors, regex, pyyaml, pillow, packaging, networkx, multidict, markupsafe, joblib, idna, fsspec, frozenlist, filelock, certifi, attrs, async-timeout, yarl, requests, nltk, lightning-utilities, jinja2, aiosignal, torch, huggingface-hub, aiohttp, torchvision, torchmetrics, timm, pytorch-lightning
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.12.2
#     Uninstalling typing_extensions-4.12.2:
#       Successfully uninstalled typing_extensions-4.12.2
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.13.1
#     Uninstalling sympy-1.13.1:
#       Successfully uninstalled sympy-1.13.1
#   Attempting uninstall: safetensors
#     Found existing installation: safetensors 0.5.3
#     Uninstalling safetensors-0.5.3:
#       Successfully uninstalled safetensors-0.5.3
#   Attempting uninstall: regex
#     Found existing installation: regex 2024.11.6
#     Uninstalling regex-2024.11.6:
#       Successfully uninstalled regex-2024.11.6
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 6.0.2
#     Uninstalling PyYAML-6.0.2:
#       Successfully uninstalled PyYAML-6.0.2
#   Attempting uninstall: pillow
#     Found existing installation: pillow 11.1.0
#     Uninstalling pillow-11.1.0:
#       Successfully uninstalled pillow-11.1.0
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.2
#     Uninstalling packaging-24.2:
#       Successfully uninstalled packaging-24.2
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.4.2
#     Uninstalling networkx-3.4.2:
#       Successfully uninstalled networkx-3.4.2
#   Attempting uninstall: multidict
#     Found existing installation: multidict 6.2.0
#     Uninstalling multidict-6.2.0:
#       Successfully uninstalled multidict-6.2.0
#   Attempting uninstall: markupsafe
#     Found existing installation: MarkupSafe 3.0.2
#     Uninstalling MarkupSafe-3.0.2:
#       Successfully uninstalled MarkupSafe-3.0.2
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.4.2
#     Uninstalling joblib-1.4.2:
#       Successfully uninstalled joblib-1.4.2
#   Attempting uninstall: idna
#     Found existing installation: idna 3.4
#     Uninstalling idna-3.4:
#       Successfully uninstalled idna-3.4
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.9.0
#     Uninstalling fsspec-2024.9.0:
#       Successfully uninstalled fsspec-2024.9.0
#   Attempting uninstall: frozenlist
#     Found existing installation: frozenlist 1.5.0
#     Uninstalling frozenlist-1.5.0:
#       Successfully uninstalled frozenlist-1.5.0
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.16.1
#     Uninstalling filelock-3.16.1:
#       Successfully uninstalled filelock-3.16.1
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2023.7.22
#     Uninstalling certifi-2023.7.22:
#       Successfully uninstalled certifi-2023.7.22
#   Attempting uninstall: attrs
#     Found existing installation: attrs 25.3.0
#     Uninstalling attrs-25.3.0:
#       Successfully uninstalled attrs-25.3.0
#   Attempting uninstall: yarl
#     Found existing installation: yarl 1.18.3
#     Uninstalling yarl-1.18.3:
#       Successfully uninstalled yarl-1.18.3
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.3
#     Uninstalling requests-2.32.3:
#       Successfully uninstalled requests-2.32.3
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.9.1
#     Uninstalling nltk-3.9.1:
#       Successfully uninstalled nltk-3.9.1
#   Attempting uninstall: jinja2
#     Found existing installation: Jinja2 3.1.4
#     Uninstalling Jinja2-3.1.4:
#       Successfully uninstalled Jinja2-3.1.4
#   Attempting uninstall: aiosignal
#     Found existing installation: aiosignal 1.3.2
#     Uninstalling aiosignal-1.3.2:
#       Successfully uninstalled aiosignal-1.3.2
#   Attempting uninstall: torch
#     Found existing installation: torch 2.6.0
#     Uninstalling torch-2.6.0:
#       Successfully uninstalled torch-2.6.0
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.29.3
#     Uninstalling huggingface-hub-0.29.3:
#       Successfully uninstalled huggingface-hub-0.29.3
#   Attempting uninstall: aiohttp
#     Found existing installation: aiohttp 3.11.14
#     Uninstalling aiohttp-3.11.14:
#       Successfully uninstalled aiohttp-3.11.14
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.21.0
#     Uninstalling torchvision-0.21.0:
#       Successfully uninstalled torchvision-0.21.0
#   Attempting uninstall: timm
#     Found existing installation: timm 1.0.15
#     Uninstalling timm-1.0.15:
#       Successfully uninstalled timm-1.0.15
# Successfully installed aiohttp-3.9.3 aiosignal-1.3.1 async-timeout-4.0.3 attrs-23.2.0 certifi-2024.2.2 filelock-3.13.1 frozenlist-1.4.1 fsspec-2024.2.0 huggingface-hub-0.20.3 idna-3.6 jinja2-3.1.3 joblib-1.3.2 lightning-utilities-0.10.1 markupsafe-2.1.5 multidict-6.0.5 networkx-3.2.1 nltk-3.8.1 packaging-23.2 pillow-10.2.0 pytorch-lightning-2.2.0.post0 pyyaml-6.0.1 regex-2023.12.25 requests-2.31.0 safetensors-0.4.2 sympy-1.12 timm-0.9.16 torch-2.2.1+cpu torchmetrics-1.3.1 torchvision-0.17.1+cpu typing-extensions-4.9.0 yarl-1.9.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ai-engine-sdk 0.1.3 requires aiohttp<4.0.0,>=3.9.5, but you have aiohttp 3.9.3 which is incompatible.
# altair 5.5.0 requires typing-extensions>=4.10.0; python_version < "3.14", but you have typing-extensions 4.9.0 which is incompatible.
# cosmpy 0.9.2 requires protobuf<5.0dev,>=4.21.6, but you have protobuf 5.29.4 which is incompatible.
# google-genai 1.8.0 requires typing-extensions<5.0.0,>=4.11.0, but you have typing-extensions 4.9.0 which is incompatible.
# langchain-google-genai 2.1.2 requires google-ai-generativelanguage<0.7.0,>=0.6.16, but you have google-ai-generativelanguage 0.6.15 which is incompatible.
# langchain-huggingface 0.1.2 requires huggingface-hub>=0.23.0, but you have huggingface-hub 0.20.3 which is incompatible.
# openai 1.69.0 requires typing-extensions<5,>=4.11, but you have typing-extensions 4.9.0 which is incompatible.
# poetry 2.1.2 requires packaging>=24.0, but you have packaging 23.2 which is incompatible.
# pydantic 2.11.1 requires typing-extensions>=4.12.2, but you have typing-extensions 4.9.0 which is incompatible.
# tensorflow-intel 2.18.0 requires ml-dtypes<0.5.0,>=0.4.0, but you have ml-dtypes 0.5.1 which is incompatible.
# tensorflow-intel 2.18.0 requires tensorboard<2.19,>=2.18, but you have tensorboard 2.19.0 which is incompatible.
# thinc 8.3.2 requires numpy<2.1.0,>=2.0.0; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# torchaudio 2.6.0+cpu requires torch==2.6.0, but you have torch 2.2.1+cpu which is incompatible.
# transformers 4.50.3 requires huggingface-hub<1.0,>=0.26.0, but you have huggingface-hub 0.20.3 which is incompatible.
# transformers 4.50.3 requires safetensors>=0.4.3, but you have safetensors 0.4.2 which is incompatible.
# typing-inspection 0.4.0 requires typing-extensions>=4.12.0, but you have typing-extensions 4.9.0 which is incompatible.
# uagents-core 0.2.0 requires requests<3.0,>=2.32.3, but you have requests 2.31.0 which is incompatible.
# Collecting antlr4-python3-runtime==4.9.3 (from -r requirements/train.txt (line 1))
#   Using cached antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting contourpy==1.2.0 (from -r requirements/train.txt (line 2))
#   Using cached contourpy-1.2.0-cp311-cp311-win_amd64.whl.metadata (5.8 kB)
# Collecting cycler==0.12.1 (from -r requirements/train.txt (line 3))
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools==4.49.0 (from -r requirements/train.txt (line 4))
#   Using cached fonttools-4.49.0-cp311-cp311-win_amd64.whl.metadata (162 kB)
# Collecting hydra-core==1.3.2 (from -r requirements/train.txt (line 5))
#   Using cached hydra_core-1.3.2-py3-none-any.whl.metadata (5.5 kB)
# Collecting imageio==2.34.0 (from -r requirements/train.txt (line 6))
#   Using cached imageio-2.34.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting imgaug==0.4.0 (from -r requirements/train.txt (line 7))
#   Using cached imgaug-0.4.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Collecting importlib-resources==6.1.1 (from -r requirements/train.txt (line 8))
#   Using cached importlib_resources-6.1.1-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: kiwisolver==1.4.5 in c:\users\bhupesh yadav\appdata\local\programs\python\python311\lib\site-packages (from -r requirements/train.txt (line 9)) (1.4.5)
# Collecting lazy-loader==0.3 (from -r requirements/train.txt (line 10))
#   Using cached lazy_loader-0.3-py3-none-any.whl.metadata (4.3 kB)
# Collecting lmdb==1.4.1 (from -r requirements/train.txt (line 11))
#   Using cached lmdb-1.4.1-cp311-cp311-win_amd64.whl.metadata (1.2 kB)
# Collecting matplotlib==3.8.3 (from -r requirements/train.txt (line 12))
#   Using cached matplotlib-3.8.3-cp311-cp311-win_amd64.whl.metadata (5.9 kB)
# Requirement already satisfied: networkx==3.2.1 in c:\users\bhupesh yadav\appdata\local\programs\python\python311\lib\site-packages (from -r requirements/train.txt (line 13)) (3.2.1)
# Requirement already satisfied: numpy==1.26.4 in c:\users\bhupesh yadav\appdata\local\programs\python\python311\lib\site-packages (from -r requirements/train.txt (line 14)) (1.26.4)
# Collecting omegaconf==2.3.0 (from -r requirements/train.txt (line 15))
#   Using cached omegaconf-2.3.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting opencv-python==4.9.0.80 (from -r requirements/train.txt (line 16))
#   Using cached opencv_python-4.9.0.80-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: packaging==23.2 in c:\users\bhupesh yadav\appdata\local\programs\python\python311\lib\site-packages (from -r requirements/train.txt (line 17)) (23.2)
# Requirement already satisfied: pillow==10.2.0 in c:\users\bhupesh yadav\appdata\local\programs\python\python311\lib\site-packages (from -r requirements/train.txt (line 18)) (10.2.0)
# Collecting protobuf==4.25.3 (from -r requirements/train.txt (line 19))
#   Using cached protobuf-4.25.3-cp310-abi3-win_amd64.whl.metadata (541 bytes)
# Requirement already satisfied: pyparsing==3.1.1 in c:\users\bhupesh yadav\appdata\local\programs\python\python311\lib\site-packages (from -r requirements/train.txt (line 20)) (3.1.1)
# Requirement already satisfied: python-dateutil==2.8.2 in c:\users\bhupesh yadav\appdata\local\programs\python\python311\lib\site-packages (from -r requirements/train.txt (line 21)) (2.8.2)
# Requirement already satisfied: pyyaml==6.0.1 in c:\users\bhupesh yadav\appdata\local\programs\python\python311\lib\site-packages (from -r requirements/train.txt (line 22)) (6.0.1)
# Collecting scikit-image==0.22.0 (from -r requirements/train.txt (line 23))
#   Using cached scikit_image-0.22.0-cp311-cp311-win_amd64.whl.metadata (13 kB)
# Requirement already satisfied: scipy==1.12.0 in c:\users\bhupesh yadav\appdata\local\programs\python\python311\lib\site-packages (from -r requirements/train.txt (line 24)) (1.12.0)
# Collecting shapely==2.0.3 (from -r requirements/train.txt (line 25))
#   Using cached shapely-2.0.3-cp311-cp311-win_amd64.whl.metadata (7.2 kB)
# Requirement already satisfied: six==1.16.0 in c:\users\bhupesh yadav\appdata\local\programs\python\python311\lib\site-packages (from -r requirements/train.txt (line 26)) (1.16.0)
# Collecting tensorboardx==2.6.2.2 (from -r requirements/train.txt (line 27))
#   Using cached tensorboardX-2.6.2.2-py2.py3-none-any.whl.metadata (5.8 kB)
# Collecting tifffile==2024.2.12 (from -r requirements/train.txt (line 28))
#   Using cached tifffile-2024.2.12-py3-none-any.whl.metadata (31 kB)
# Collecting zipp==3.17.0 (from -r requirements/train.txt (line 29))
#   Using cached zipp-3.17.0-py3-none-any.whl.metadata (3.7 kB)
# Using cached contourpy-1.2.0-cp311-cp311-win_amd64.whl (187 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.49.0-cp311-cp311-win_amd64.whl (2.2 MB)
# Using cached hydra_core-1.3.2-py3-none-any.whl (154 kB)
# Using cached imageio-2.34.0-py3-none-any.whl (313 kB)
# Using cached imgaug-0.4.0-py2.py3-none-any.whl (948 kB)
# Using cached importlib_resources-6.1.1-py3-none-any.whl (33 kB)
# Using cached lazy_loader-0.3-py3-none-any.whl (9.1 kB)
# Using cached lmdb-1.4.1-cp311-cp311-win_amd64.whl (100 kB)
# Using cached matplotlib-3.8.3-cp311-cp311-win_amd64.whl (7.6 MB)
# Using cached omegaconf-2.3.0-py3-none-any.whl (79 kB)
# Downloading opencv_python-4.9.0.80-cp37-abi3-win_amd64.whl (38.6 MB)
#    ---------------------------------------- 0.0/38.6 MB ? eta -:--:--
#     --------------------------------------- 0.5/38.6 MB 3.4 MB/s eta 0:00:12
#    - -------------------------------------- 1.0/38.6 MB 3.4 MB/s eta 0:00:12
#    - -------------------------------------- 1.8/38.6 MB 3.0 MB/s eta 0:00:13
#    -- ------------------------------------- 2.1/38.6 MB 2.7 MB/s eta 0:00:14
#    -- ------------------------------------- 2.6/38.6 MB 2.7 MB/s eta 0:00:14
#    --- ------------------------------------ 3.4/38.6 MB 2.8 MB/s eta 0:00:13
#    ---- ----------------------------------- 3.9/38.6 MB 2.8 MB/s eta 0:00:13
#    ---- ----------------------------------- 4.5/38.6 MB 2.9 MB/s eta 0:00:12
#    ----- ---------------------------------- 5.2/38.6 MB 2.9 MB/s eta 0:00:12
#    ----- ---------------------------------- 5.8/38.6 MB 2.9 MB/s eta 0:00:12
#    ------ --------------------------------- 6.6/38.6 MB 3.0 MB/s eta 0:00:11
#    ------- -------------------------------- 7.3/38.6 MB 3.0 MB/s eta 0:00:11
#    -------- ------------------------------- 8.1/38.6 MB 3.1 MB/s eta 0:00:10
#    --------- ------------------------------ 8.9/38.6 MB 3.1 MB/s eta 0:00:10
#    ---------- ----------------------------- 9.7/38.6 MB 3.2 MB/s eta 0:00:10
#    ---------- ----------------------------- 10.5/38.6 MB 3.2 MB/s eta 0:00:09
#    ----------- ---------------------------- 11.0/38.6 MB 3.2 MB/s eta 0:00:09
#    ------------ --------------------------- 11.8/38.6 MB 3.2 MB/s eta 0:00:09
#    ------------- -------------------------- 12.6/38.6 MB 3.2 MB/s eta 0:00:09
#    ------------- -------------------------- 13.4/38.6 MB 3.2 MB/s eta 0:00:08
#    -------------- ------------------------- 13.9/38.6 MB 3.2 MB/s eta 0:00:08
#    --------------- ------------------------ 14.7/38.6 MB 3.2 MB/s eta 0:00:08
#    --------------- ------------------------ 15.2/38.6 MB 3.2 MB/s eta 0:00:08
#    ---------------- ----------------------- 15.7/38.6 MB 3.2 MB/s eta 0:00:08
#    ---------------- ----------------------- 16.3/38.6 MB 3.2 MB/s eta 0:00:08
#    ----------------- ---------------------- 16.8/38.6 MB 3.2 MB/s eta 0:00:07
#    ----------------- ---------------------- 17.3/38.6 MB 3.1 MB/s eta 0:00:07
#    ------------------ --------------------- 17.8/38.6 MB 3.1 MB/s eta 0:00:07
#    ------------------- -------------------- 18.4/38.6 MB 3.1 MB/s eta 0:00:07
#    ------------------- -------------------- 18.9/38.6 MB 3.0 MB/s eta 0:00:07
#    -------------------- ------------------- 19.4/38.6 MB 3.0 MB/s eta 0:00:07
#    -------------------- ------------------- 19.7/38.6 MB 3.0 MB/s eta 0:00:07
#    -------------------- ------------------- 20.2/38.6 MB 3.0 MB/s eta 0:00:07
#    --------------------- ------------------ 20.4/38.6 MB 3.0 MB/s eta 0:00:07
#    --------------------- ------------------ 21.0/38.6 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.5/38.6 MB 2.9 MB/s eta 0:00:06
#    ---------------------- ----------------- 22.0/38.6 MB 2.9 MB/s eta 0:00:06
#    ----------------------- ---------------- 22.3/38.6 MB 2.9 MB/s eta 0:00:06
#    ----------------------- ---------------- 22.8/38.6 MB 2.9 MB/s eta 0:00:06
#    ------------------------ --------------- 23.3/38.6 MB 2.9 MB/s eta 0:00:06
#    ------------------------ --------------- 23.9/38.6 MB 2.8 MB/s eta 0:00:06
#    ------------------------- -------------- 24.4/38.6 MB 2.8 MB/s eta 0:00:06
#    ------------------------- -------------- 24.6/38.6 MB 2.8 MB/s eta 0:00:05
#    ------------------------- -------------- 24.9/38.6 MB 2.8 MB/s eta 0:00:05
#    -------------------------- ------------- 25.4/38.6 MB 2.8 MB/s eta 0:00:05
#    -------------------------- ------------- 26.0/38.6 MB 2.7 MB/s eta 0:00:05
#    --------------------------- ------------ 26.5/38.6 MB 2.7 MB/s eta 0:00:05
#    --------------------------- ------------ 27.0/38.6 MB 2.7 MB/s eta 0:00:05
#    ---------------------------- ----------- 27.5/38.6 MB 2.7 MB/s eta 0:00:05
#    ----------------------------- ---------- 28.3/38.6 MB 2.8 MB/s eta 0:00:04
#    ----------------------------- ---------- 28.8/38.6 MB 2.8 MB/s eta 0:00:04
#    ------------------------------ --------- 29.4/38.6 MB 2.8 MB/s eta 0:00:04
#    ------------------------------ --------- 29.6/38.6 MB 2.7 MB/s eta 0:00:04
#    ------------------------------- -------- 30.4/38.6 MB 2.7 MB/s eta 0:00:03
#    -------------------------------- ------- 30.9/38.6 MB 2.7 MB/s eta 0:00:03
#    -------------------------------- ------- 31.5/38.6 MB 2.7 MB/s eta 0:00:03
#    --------------------------------- ------ 32.0/38.6 MB 2.7 MB/s eta 0:00:03
#    --------------------------------- ------ 32.5/38.6 MB 2.7 MB/s eta 0:00:03
#    ---------------------------------- ----- 33.0/38.6 MB 2.7 MB/s eta 0:00:03
#    ---------------------------------- ----- 33.3/38.6 MB 2.7 MB/s eta 0:00:02
#    ----------------------------------- ---- 33.8/38.6 MB 2.7 MB/s eta 0:00:02
#    ----------------------------------- ---- 34.1/38.6 MB 2.7 MB/s eta 0:00:02
#    ----------------------------------- ---- 34.6/38.6 MB 2.7 MB/s eta 0:00:02
#    ------------------------------------ --- 34.9/38.6 MB 2.7 MB/s eta 0:00:02
#    ------------------------------------ --- 35.4/38.6 MB 2.7 MB/s eta 0:00:02
#    ------------------------------------- -- 35.9/38.6 MB 2.6 MB/s eta 0:00:02
#    ------------------------------------- -- 36.2/38.6 MB 2.6 MB/s eta 0:00:01
#    ------------------------------------- -- 36.4/38.6 MB 2.6 MB/s eta 0:00:01
#    -------------------------------------- - 37.0/38.6 MB 2.6 MB/s eta 0:00:01
#    -------------------------------------- - 37.2/38.6 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------------  38.0/38.6 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------------  38.5/38.6 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------------- 38.6/38.6 MB 2.6 MB/s eta 0:00:00
# Downloading protobuf-4.25.3-cp310-abi3-win_amd64.whl (413 kB)
# Downloading scikit_image-0.22.0-cp311-cp311-win_amd64.whl (24.5 MB)
#    ---------------------------------------- 0.0/24.5 MB ? eta -:--:--
#     --------------------------------------- 0.5/24.5 MB 2.8 MB/s eta 0:00:09
#    - -------------------------------------- 1.0/24.5 MB 3.4 MB/s eta 0:00:07
#    -- ------------------------------------- 1.8/24.5 MB 3.2 MB/s eta 0:00:07
#    ---- ----------------------------------- 2.6/24.5 MB 3.4 MB/s eta 0:00:07
#    ----- ---------------------------------- 3.4/24.5 MB 3.4 MB/s eta 0:00:07
#    ------ --------------------------------- 3.9/24.5 MB 3.3 MB/s eta 0:00:07
#    ------- -------------------------------- 4.7/24.5 MB 3.3 MB/s eta 0:00:06
#    -------- ------------------------------- 5.2/24.5 MB 3.3 MB/s eta 0:00:06
#    --------- ------------------------------ 6.0/24.5 MB 3.3 MB/s eta 0:00:06
#    ---------- ----------------------------- 6.6/24.5 MB 3.3 MB/s eta 0:00:06
#    ----------- ---------------------------- 7.3/24.5 MB 3.3 MB/s eta 0:00:06
#    ------------- -------------------------- 8.4/24.5 MB 3.4 MB/s eta 0:00:05
#    -------------- ------------------------- 9.2/24.5 MB 3.4 MB/s eta 0:00:05
#    ---------------- ----------------------- 10.0/24.5 MB 3.5 MB/s eta 0:00:05
#    ----------------- ---------------------- 10.7/24.5 MB 3.5 MB/s eta 0:00:04
#    ------------------ --------------------- 11.3/24.5 MB 3.5 MB/s eta 0:00:04
#    ------------------- -------------------- 12.1/24.5 MB 3.4 MB/s eta 0:00:04
#    -------------------- ------------------- 12.6/24.5 MB 3.4 MB/s eta 0:00:04
#    --------------------- ------------------ 13.4/24.5 MB 3.4 MB/s eta 0:00:04
#    ----------------------- ---------------- 14.2/24.5 MB 3.4 MB/s eta 0:00:04
#    ----------------------- ---------------- 14.7/24.5 MB 3.4 MB/s eta 0:00:03
#    ------------------------- -------------- 15.5/24.5 MB 3.4 MB/s eta 0:00:03
#    -------------------------- ------------- 16.0/24.5 MB 3.3 MB/s eta 0:00:03
#    --------------------------- ------------ 16.8/24.5 MB 3.3 MB/s eta 0:00:03
#    ---------------------------- ----------- 17.6/24.5 MB 3.4 MB/s eta 0:00:03
#    ----------------------------- ---------- 18.1/24.5 MB 3.4 MB/s eta 0:00:02
#    ------------------------------ --------- 18.9/24.5 MB 3.4 MB/s eta 0:00:02
#    ------------------------------- -------- 19.4/24.5 MB 3.4 MB/s eta 0:00:02
#    -------------------------------- ------- 20.2/24.5 MB 3.4 MB/s eta 0:00:02
#    --------------------------------- ------ 20.7/24.5 MB 3.3 MB/s eta 0:00:02
#    ----------------------------------- ---- 21.5/24.5 MB 3.3 MB/s eta 0:00:01
#    ------------------------------------ --- 22.3/24.5 MB 3.4 MB/s eta 0:00:01
#    ------------------------------------- -- 22.8/24.5 MB 3.4 MB/s eta 0:00:01
#    -------------------------------------- - 23.6/24.5 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------  24.4/24.5 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------- 24.5/24.5 MB 3.4 MB/s eta 0:00:00
# Downloading shapely-2.0.3-cp311-cp311-win_amd64.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    --------------------- ------------------ 0.8/1.4 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 3.8 MB/s eta 0:00:00
# Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl (101 kB)
# Downloading tifffile-2024.2.12-py3-none-any.whl (224 kB)
# Downloading zipp-3.17.0-py3-none-any.whl (7.4 kB)
# Building wheels for collected packages: antlr4-python3-runtime
#   Building wheel for antlr4-python3-runtime (setup.py): started
#   Building wheel for antlr4-python3-runtime (setup.py): finished with status 'done'
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144578 sha256=b93159e9284fb43b2f9efd54b87682be045a3b46b7afd93afd2f512e1cafe726
#   Stored in directory: c:\users\bhupesh yadav\appdata\local\pip\cache\wheels\1a\97\32\461f837398029ad76911109f07047fde1d7b661a147c7c56d1
# Successfully built antlr4-python3-runtime
# Installing collected packages: lmdb, antlr4-python3-runtime, zipp, tifffile, shapely, protobuf, opencv-python, omegaconf, lazy-loader, importlib-resources, imageio, fonttools, cycler, contourpy, tensorboardx, scikit-image, matplotlib, hydra-core, imgaug
#   Attempting uninstall: zipp
#     Found existing installation: zipp 3.20.2
#     Uninstalling zipp-3.20.2:
#       Successfully uninstalled zipp-3.20.2
#   Attempting uninstall: tifffile
#     Found existing installation: tifffile 2025.3.13
#     Uninstalling tifffile-2025.3.13:
#       Successfully uninstalled tifffile-2025.3.13
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.4
#     Uninstalling protobuf-5.29.4:
#       Successfully uninstalled protobuf-5.29.4
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.10.0.84
#     Uninstalling opencv-python-4.10.0.84:
#       Successfully uninstalled opencv-python-4.10.0.84
#   Attempting uninstall: lazy-loader
#     Found existing installation: lazy_loader 0.4
#     Uninstalling lazy_loader-0.4:
#       Successfully uninstalled lazy_loader-0.4
#   Attempting uninstall: imageio
#     Found existing installation: imageio 2.37.0
#     Uninstalling imageio-2.37.0:
#       Successfully uninstalled imageio-2.37.0
#   Attempting uninstall: fonttools
#     Found existing installation: fonttools 4.42.1
#     Uninstalling fonttools-4.42.1:
#       Successfully uninstalled fonttools-4.42.1
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.11.0
#     Uninstalling cycler-0.11.0:
#       Successfully uninstalled cycler-0.11.0
#   Attempting uninstall: contourpy
#     Found existing installation: contourpy 1.1.1
#     Uninstalling contourpy-1.1.1:
#       Successfully uninstalled contourpy-1.1.1
#   Attempting uninstall: scikit-image
#     Found existing installation: scikit-image 0.25.2
#     Uninstalling scikit-image-0.25.2:
#       Successfully uninstalled scikit-image-0.25.2
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.8.0
#     Uninstalling matplotlib-3.8.0:
#       Successfully uninstalled matplotlib-3.8.0
# Successfully installed antlr4-python3-runtime-4.9.3 contourpy-1.2.0 cycler-0.12.1 fonttools-4.49.0 hydra-core-1.3.2 imageio-2.34.0 imgaug-0.4.0 importlib-resources-6.1.1 lazy-loader-0.3 lmdb-1.4.1 matplotlib-3.8.3 omegaconf-2.3.0 opencv-python-4.9.0.80 protobuf-4.25.3 scikit-image-0.22.0 shapely-2.0.3 tensorboardx-2.6.2.2 tifffile-2024.2.12 zipp-3.17.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# grpcio-status 1.71.0 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 4.25.3 which is incompatible.
# importlib-metadata 8.5.0 requires zipp>=3.20, but you have zipp 3.17.0 which is incompatible.
# langchain-google-genai 2.1.2 requires google-ai-generativelanguage<0.7.0,>=0.6.16, but you have google-ai-generativelanguage 0.6.15 which is incompatible.
# poetry 2.1.2 requires packaging>=24.0, but you have packaging 23.2 which is incompatible.
# tensorflow-intel 2.18.0 requires ml-dtypes<0.5.0,>=0.4.0, but you have ml-dtypes 0.5.1 which is incompatible.
# tensorflow-intel 2.18.0 requires tensorboard<2.19,>=2.18, but you have tensorboard 2.19.0 which is incompatible.
# Requirement already satisfied: lmdb==1.4.1 in c:\users\bhupesh yadav\appdata\local\programs\python\python311\lib\site-packages (from -r requirements/test.txt (line 1)) (1.4.1)
# Requirement already satisfied: pillow==10.2.0 in c:\users\bhupesh yadav\appdata\local\programs\python\python311\lib\site-packages (from -r requirements/test.txt (line 2)) (10.2.0)
# Requirement already satisfied: tqdm==4.66.2 in c:\users\bhupesh yadav\appdata\local\programs\python\python311\lib\site-packages (from -r requirements/test.txt (line 3)) (4.66.2)
# Requirement already satisfied: colorama in c:\users\bhupesh yadav\appdata\local\programs\python\python311\lib\site-packages (from tqdm==4.66.2->-r requirements/test.txt (line 3)) (0.4.6)

# %%
# !python run_parseq.py
# Out:
# Predicted text: LIVERSITE
# c:\Users\Bhupesh Yadav\AppData\Local\Programs\Python\Python311\Lib\site-packages\huggingface_hub\utils\_runtime.py:184: UserWarning: Pydantic is installed but cannot be imported. Please check your installation. `huggingface_hub` will default to not using Pydantic. Error message: '{e}'
#   warnings.warn(
# Using cache found in C:\Users\Bhupesh Yadav/.cache\torch\hub\baudm_parseq_main

# %%
# !python test.py pretrained=parseq \
  --img_folder data/test/demo/ \
  --label_file data/test/demo/labels.txt \
  --device cpu
# Out:
# Additional keyword arguments: {'charset_test': '0123456789abcdefghijklmnopqrstuvwxyz'}
# Writing predictions to: pretrained=parseq.predictions.txt
# | Dataset | # samples | Accuracy | 1 - NED | Confidence | Label Length |
# |:-------:|----------:|---------:|--------:|-----------:|-------------:|
# | Custom  |         7 |    42.86 |   58.58 |       0.53 |        12.00 |
# c:\Users\Bhupesh Yadav\AppData\Local\Programs\Python\Python311\Lib\site-packages\huggingface_hub\utils\_runtime.py:184: UserWarning: Pydantic is installed but cannot be imported. Please check your installation. `huggingface_hub` will default to not using Pydantic. Error message: '{e}'
#   warnings.warn(
#
# Testing:   0%|          | 0/1 [00:00<?, ?it/s]c:\Users\Bhupesh Yadav\AppData\Local\Programs\Python\Python311\Lib\site-packages\huggingface_hub\utils\_runtime.py:184: UserWarning: Pydantic is installed but cannot be imported. Please check your installation. `huggingface_hub` will default to not using Pydantic. Error message: '{e}'
#   warnings.warn(
# c:\Users\Bhupesh Yadav\AppData\Local\Programs\Python\Python311\Lib\site-packages\huggingface_hub\utils\_runtime.py:184: UserWarning: Pydantic is installed but cannot be imported. Please check your installation. `huggingface_hub` will default to not using Pydantic. Error message: '{e}'
#   warnings.warn(
# c:\Users\Bhupesh Yadav\AppData\Local\Programs\Python\Python311\Lib\site-packages\huggingface_hub\utils\_runtime.py:184: UserWarning: Pydantic is installed but cannot be imported. Please check your installation. `huggingface_hub` will default to not using Pydantic. Error message: '{e}'
#   warnings.warn(
# c:\Users\Bhupesh Yadav\AppData\Local\Programs\Python\Python311\Lib\site-packages\huggingface_hub\utils\_runtime.py:184: UserWarning: Pydantic is installed but cannot be imported. Please check your installation. `huggingface_hub` will default to not using Pydantic. Error message: '{e}'
#   warnings.warn(
#
# Testing: 100%|██████████| 1/1 [00:06<00:00,  6.84s/it]
# Testing: 100%|██████████| 1/1 [00:07<00:00,  7.43s/it]
